# %%
import pandas as pd
import sys
sys.path.insert(0, '../src/SwiftGrasp')
from utils import *


from yahoofinancials import YahooFinancials

import datetime
from dateutil.relativedelta import relativedelta

# %%
# obj = 'AAPL'
# yf = YahooFinancials(obj)
# # today = datetime.datetime.today()
# # seven_days_ago = today - relativedelta(days=8)
# # today_prices = yf.get_historical_price_data(seven_days_ago.strftime('%Y-%m-%d'), today.strftime('%Y-%m-%d'), 'weekly')
# # today_prices = yf.get_historical_price_data('1940-12-01', '1940-12-31', 'weekly')

# yf.get_key_statistics_data()

# %%
stock_ticker = 'AAPL'
fsd = FinancialStatementData(stock_ticker)

# %%
df1 = fsd.get_balance_sheet()
df1
# Out:
#                totalLiab  totalStockholderEquity  otherCurrentLiab  \
# 2022-06-25  278202000000             58107000000       56539000000
# 2022-03-26  283263000000             67399000000       58168000000
# 2021-12-25  309259000000             71932000000       57043000000
# 2021-09-25  287912000000             63090000000       53577000000
#
#              totalAssets  commonStock  otherCurrentAssets  retainedEarnings  \
# 2022-06-25  336309000000  62115000000         16386000000        5289000000
# 2022-03-26  350662000000  61181000000         15809000000       12712000000
# 2021-12-25  381191000000  58424000000         18112000000       14435000000
# 2021-09-25  351002000000  57365000000         14111000000        5562000000
#
#               otherLiab  treasuryStock  otherAssets  ...  \
# 2022-06-25  53629000000    -9297000000  52605000000  ...
# 2022-03-26  52432000000    -6494000000  51959000000  ...
# 2021-12-25  55056000000     -927000000  50109000000  ...
# ...

# %%
df3 = fsd.get_income_statement()
df3
# Out:
#             researchDevelopment effectOfAccountingCharges  incomeBeforeTax  \
# 2022-06-25           6797000000                      None      23066000000
# 2022-03-26           6387000000                      None      30139000000
# 2021-12-25           6306000000                      None      41241000000
# 2021-09-25           5772000000                      None      23248000000
#
#            minorityInterest    netIncome  sellingGeneralAdministrative  \
# 2022-06-25             None  19442000000                    6012000000
# 2022-03-26             None  25010000000                    6193000000
# 2021-12-25             None  34630000000                    6449000000
# 2021-09-25             None  20551000000                    5616000000
#
#             grossProfit         ebit  operatingIncome otherOperatingExpenses  \
# 2022-06-25  35885000000  23076000000      23076000000                   None
# 2022-03-26  42559000000  29979000000      29979000000                   None
# ...

# %%
df4 = fsd.get_cash_statement()
df4
# Out:
#             investments  changeToLiabilities  \
# 2022-06-25   6953000000          -4725000000
# 2022-03-26  -6390000000         -21398000000
# 2021-12-25 -12929000000          20275000000
# 2021-09-25   4608000000          14050000000
#
#             totalCashflowsFromInvestingActivities  netBorrowings  \
# 2022-06-25                             4234000000      971000000
# 2022-03-26                            -9265000000    -1751000000
# 2021-12-25                           -16106000000    -1000000000
# 2021-09-25                              835000000     3220000000
#
#             totalCashFromFinancingActivities  changeToOperatingActivities  \
# 2022-06-25                      -27445000000                   2497000000
# 2022-03-26                      -28351000000                   9486000000
# 2021-12-25                      -28159000000                 -10497000000
# 2021-09-25                      -20382000000                  -5602000000
#
# ...

# %%
sd = StockData(stock_ticker)
df2 = sd.get_stock()
df2.head()
# Out:
#          date       high        low       open      close     volume  \
# 0  1564579800  55.342499  52.825001  54.105000  53.259998  277125600
# 1  1564666200  54.507500  51.685001  53.474998  52.107498  216071600
# 2  1564752600  51.607498  50.407501  51.382500  51.005001  163448400
# 3  1565011800  49.662498  48.145000  49.497501  48.334999  209572000
# 4  1565098200  49.517502  48.509998  49.077499  49.250000  143299200
#
#     adjclose formatted_date
# 0  51.982613     2019-07-31
# 1  50.857750     2019-08-01
# 2  49.781704     2019-08-02
# 3  47.175735     2019-08-05
# 4  48.068783     2019-08-06

# %%
fsd.get_income_statement()
# Out:
#             researchDevelopment effectOfAccountingCharges  incomeBeforeTax  \
# 2022-03-26           6387000000                      None      30139000000
# 2021-12-25           6306000000                      None      41241000000
# 2021-09-25           5772000000                      None      23248000000
# 2021-06-26           5717000000                      None      24369000000
#
#            minorityInterest    netIncome  sellingGeneralAdministrative  \
# 2022-03-26             None  25010000000                    6193000000
# 2021-12-25             None  34630000000                    6449000000
# 2021-09-25             None  20551000000                    5616000000
# 2021-06-26             None  21744000000                    5412000000
#
#             grossProfit         ebit  operatingIncome otherOperatingExpenses  \
# 2022-03-26  42559000000  29979000000      29979000000                   None
# 2021-12-25  54243000000  41488000000      41488000000                   None
# ...

# %%
fsd.get_cash_statement()
# Out:
#             investments  changeToLiabilities  \
# 2022-03-26  -6390000000         -21398000000
# 2021-12-25 -12929000000          20275000000
# 2021-09-25   4608000000          14050000000
# 2021-06-26   5747000000            307000000
#
#             totalCashflowsFromInvestingActivities  netBorrowings  \
# 2022-03-26                            -9265000000    -1751000000
# 2021-12-25                           -16106000000    -1000000000
# 2021-09-25                              835000000     3220000000
# 2021-06-26                             3572000000     3220000000
#
#             totalCashFromFinancingActivities  changeToOperatingActivities  \
# 2022-03-26                      -28351000000                   9486000000
# 2021-12-25                      -28159000000                 -10497000000
# 2021-09-25                      -20382000000                  -5602000000
# 2021-06-26                      -29396000000                  -6048000000
#
# ...

# %%
## Original data types
stock_ticker = 'AAPL'
yf = YahooFinancials(stock_ticker)
balance_sheet_data_qt = yf.get_financial_stmts(frequency = 'annual', statement_type = 'cash')
balance_sheet_data_qt
# Out:
# {'cashflowStatementHistory': {'AAPL': [{'2021-09-25': {'investments': -2819000000,
#      'changeToLiabilities': 14002000000,
#      'totalCashflowsFromInvestingActivities': -14545000000,
#      'netBorrowings': 12665000000,
#      'totalCashFromFinancingActivities': -93353000000,
#      'changeToOperatingActivities': -6146000000,
#      'issuanceOfStock': 1105000000,
#      'netIncome': 94680000000,
#      'changeInCash': -3860000000,
#      'repurchaseOfStock': -92527000000,
#      'totalCashFromOperatingActivities': 104038000000,
#      'depreciation': 11284000000,
#      'otherCashflowsFromInvestingActivities': -608000000,
#      'dividendsPaid': -14467000000,
#      'changeToInventory': -2642000000,
#      'changeToAccountReceivables': -10125000000,
#      'otherCashflowsFromFinancingActivities': -129000000,
#      'changeToNetincome': 2985000000,
#      'capitalExpenditures': -11085000000}},
#    {'2020-09-26': {'investments': 5335000000,
# ...
